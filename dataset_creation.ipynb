# %%
import pandas as pd
import csv

file_path = 'createdDataset.csv'
df = pd.read_csv(file_path, encoding='iso-8859-1')
df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
df.columns = df.columns.str.strip()
df.head()
# Out:
#          rec_id given_name  surname street_number    address_1  \
# 0  rec-52-dup-0     Yoland   Mencjs             7      Hydw St
# 1   rec-915-org       Kona  Elliott            42  Lincoln Ave
# 2   rec-199-org      Kamea  Kennedy            12   Wailele St
# 3   rec-996-org  Dominique  Fleming           110    Hauiki St
# 4   rec-195-org      Ciera      Pua            27  Puowaina Dr
#
#                 suburb postcode state date_of_birth age phone_number  \
# 0            Kaumakani    90290    hi      19311124  24  206 9589621
# 1           Pearl City    89133    az      19320408  35  423 9346799
# 2              Volcano    85258    az      19760705  35  213 0356038
# 3  Hawaiian Ocean View    85030    az      19431130  32  808 1076447
# 4              Wahiawa    90290    hi      19470119  37  808 0257265
#
#   soc_sec_id  blocking_number
# 0                           1
# 1    7657030                7
# 2                           4
# 3                           0
# 4    4354584                1

# %%
original_df = df[df['rec_id'].str.contains('-org', na=False)]
original_df.head()
# Out:
#         rec_id given_name  surname street_number    address_1  \
# 1  rec-915-org       Kona  Elliott            42  Lincoln Ave
# 2  rec-199-org      Kamea  Kennedy            12   Wailele St
# 3  rec-996-org  Dominique  Fleming           110    Hauiki St
# 4  rec-195-org      Ciera      Pua            27  Puowaina Dr
# 5  rec-524-org   Adelaide  Padilla            11    Kekona Pl
#
#                 suburb postcode state date_of_birth age phone_number  \
# 1           Pearl City    89133    az      19320408  35  423 9346799
# 2              Volcano    85258    az      19760705  35  213 0356038
# 3  Hawaiian Ocean View    85030    az      19431130  32  808 1076447
# 4              Wahiawa    90290    hi      19470119  37  808 0257265
# 5               Olinda    89137    wa      20190608  29  253 7227405
#
#   soc_sec_id  blocking_number
# 1    7657030                7
# 2                           4
# 3                           0
# 4    4354584                1
# 5                           0

# %%
original_count = original_df.shape[0]
original_count
# Out:
# 1000

# %%
duplicate_df = df[df['rec_id'].str.contains('-dup', na=False)]
duplicate_df.head()
# Out:
#            rec_id given_name  surname street_number       address_1  \
# 0    rec-52-dup-0     Yoland   Mencjs             7         Hydw St
# 14  rec-120-dup-0     Lennox   Tamajo            24  Hanauma Bay Rd
# 15  rec-891-dup-0       Aala                   1708     Puakauhi Ct
# 18  rec-191-dup-0   Isabella   Tucker            56     St Ohialoke
# 21  rec-828-dup-0     Anitga  Muramto            91    Peter Lee Rd
#
#         suburb     postcode state date_of_birth age phone_number soc_sec_id  \
# 0    Kaumakani        90290    hi      19311124  24  206 9589621
# 14       8913c  Princeville    hi      19280408  30  310 6255922
# 15    Mokuleia        85208    nv      19720409      206 7456375    3773764
# 18  'Puiapani'        85011    wa      19921101  62  253 9215064    1722381
# 21    Volcanro        96748    nv      19220308  30  808 5347407    4417732
#
#     blocking_number
# 0                 1
# 14                6
# 15                2
# 18                3
# 21                7

# %%
duplicate_count = duplicate_df.shape[0]
duplicate_count
# Out:
# 300

# %%
random_sample = original_df.sample(n=200, random_state=42)
dataset_2 = pd.concat([duplicate_df, random_sample])
dataset_1 = original_df.drop(random_sample.index)

# %%
dataset_1_count = dataset_1.shape[0]
dataset_1_count
# Out:
# 800

# %%
dataset_2_count = dataset_2.shape[0]
dataset_2_count
# Out:
# 500

# %%
dataset_1.to_csv('dataset1.csv', index=False)
dataset_2.to_csv('dataset2.csv', index=False)

# %%
clean_df = df.copy()
clean_df['rec_id'] = clean_df['rec_id'].str.replace(r'-org|-dup-\d+', '', regex=True)

# Display the new dataframe with cleaned rec_id
clean_df.head()
# Out:
#     rec_id given_name  surname street_number    address_1  \
# 0   rec-52     Yoland   Mencjs             7      Hydw St
# 1  rec-915       Kona  Elliott            42  Lincoln Ave
# 2  rec-199      Kamea  Kennedy            12   Wailele St
# 3  rec-996  Dominique  Fleming           110    Hauiki St
# 4  rec-195      Ciera      Pua            27  Puowaina Dr
#
#                 suburb postcode state date_of_birth age phone_number  \
# 0            Kaumakani    90290    hi      19311124  24  206 9589621
# 1           Pearl City    89133    az      19320408  35  423 9346799
# 2              Volcano    85258    az      19760705  35  213 0356038
# 3  Hawaiian Ocean View    85030    az      19431130  32  808 1076447
# 4              Wahiawa    90290    hi      19470119  37  808 0257265
#
#   soc_sec_id  blocking_number
# 0                           1
# 1    7657030                7
# 2                           4
# 3                           0
# 4    4354584                1

# %%
clean_df.columns = clean_df.columns.str.strip()
matching_records = clean_df[clean_df.duplicated(subset=['rec_id', 'date_of_birth'], keep=False)]
num_matching_records = matching_records.shape[0]
print(f"Number of records with matching 'rec_id' and 'date_of_birth': {num_matching_records}")
matching_records.head()
# Out:
# Number of records with matching 'rec_id' and 'date_of_birth': 580
#     rec_id given_name  surname street_number    address_1  \
# 0   rec-52     Yoland   Mencjs             7      Hydw St
# 2  rec-199      Kamea  Kennedy            12   Wailele St
# 3  rec-996  Dominique  Fleming           110    Hauiki St
# 4  rec-195      Ciera      Pua            27  Puowaina Dr
# 9   rec-66   Lawrence   Felipe             4    Kapahu St
#
#                 suburb postcode state date_of_birth age phone_number  \
# 0            Kaumakani    90290    hi      19311124  24  206 9589621
# 2              Volcano    85258    az      19760705  35  213 0356038
# 3  Hawaiian Ocean View    85030    az      19431130  32  808 1076447
# 4              Wahiawa    90290    hi      19470119  37  808 0257265
# 9              Volcano    85079    hi      19950422  29  602 6471003
#
#   soc_sec_id  blocking_number
# 0                           1
# 2                           4
# 3                           0
# 4    4354584                1
# 9                           5

# %%
df = df.replace(r'^\s*$', pd.NA, regex=True)
clean_df.head()
# Out:
#     rec_id given_name  surname street_number    address_1  \
# 0   rec-52     Yoland   Mencjs             7      Hydw St
# 1  rec-915       Kona  Elliott            42  Lincoln Ave
# 2  rec-199      Kamea  Kennedy            12   Wailele St
# 3  rec-996  Dominique  Fleming           110    Hauiki St
# 4  rec-195      Ciera      Pua            27  Puowaina Dr
#
#                 suburb postcode state date_of_birth age phone_number  \
# 0            Kaumakani    90290    hi      19311124  24  206 9589621
# 1           Pearl City    89133    az      19320408  35  423 9346799
# 2              Volcano    85258    az      19760705  35  213 0356038
# 3  Hawaiian Ocean View    85030    az      19431130  32  808 1076447
# 4              Wahiawa    90290    hi      19470119  37  808 0257265
#
#   soc_sec_id  blocking_number
# 0                           1
# 1    7657030                7
# 2                           4
# 3                           0
# 4    4354584                1

# %%
num_missing_dob = df['date_of_birth'].isna().sum()
num_missing_dob
# Out:
# np.int64(107)

# %%
clean_df.columns = clean_df.columns.str.strip()
matching_records_soc = clean_df[clean_df.duplicated(subset=['rec_id', 'soc_sec_id'], keep=False)]
num_matching_records_soc = matching_records_soc.shape[0]
print(f"Number of records with matching 'rec_id' and 'social security id': {num_matching_records_soc}")
matching_records_soc.head()
# Out:
# Number of records with matching 'rec_id' and 'social security id': 460
#     rec_id given_name  surname street_number    address_1  \
# 0   rec-52     Yoland   Mencjs             7      Hydw St
# 2  rec-199      Kamea  Kennedy            12   Wailele St
# 3  rec-996  Dominique  Fleming           110    Hauiki St
# 4  rec-195      Ciera      Pua            27  Puowaina Dr
# 9   rec-66   Lawrence   Felipe             4    Kapahu St
#
#                 suburb postcode state date_of_birth age phone_number  \
# 0            Kaumakani    90290    hi      19311124  24  206 9589621
# 2              Volcano    85258    az      19760705  35  213 0356038
# 3  Hawaiian Ocean View    85030    az      19431130  32  808 1076447
# 4              Wahiawa    90290    hi      19470119  37  808 0257265
# 9              Volcano    85079    hi      19950422  29  602 6471003
#
#   soc_sec_id  blocking_number
# 0                           1
# 2                           4
# 3                           0
# 4    4354584                1
# 9                           5

# %%
num_missing_soc = df['soc_sec_id'].isna().sum()
num_missing_soc
# Out:
# np.int64(688)
